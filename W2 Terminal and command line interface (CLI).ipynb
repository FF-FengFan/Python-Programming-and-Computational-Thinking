# %% [markdown]
# ### Designing a Program
# The Program Development Cycle
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Pseudocode
#
# Input the hours worked
# \
# Input the hourly pay rate
# \
# Calculate gross pay as hours worked multiplied by pay rate
# \
# Display the gross pay

# %%
## 1. request the # of hours worked
input('what is the number of hours you worked?')
## 2. request the hourly pay rate
input('What is the hourly pay rate?')
## 3. calculate the gross pay
gross_pay = hours*payrate
## 4. display gross pay
print("This is your gross pay", gross_pay)

# %% [markdown]
# ### Flowchart
# ![image-9.png](attachment:image-9.png)

# %% [markdown]
# ### Computer Terminal
# A computer terminal is an electronic or electromechanical hardware device that can be used for entering data into, and transcribing data from, a computer or a computing system.
#
# 1. A shell is the program that you interact with when running commands in a terminal.
# 2. A command-line interface (CLI) is a program designed to run in a shell inside the terminal.
# The shell provides the commands that you use in a command-line interface, and the terminal is the application that you run to access the shell.

# %% [markdown]
# ### Access the Terminal
# 1. Linux or macOS, built in terminal
# 2. Windows (Command Prompt): Windows 10 or below, download from the Microsoft store: https://apps.microsoft.com/store/detail/windows-terminal/9N0DX20HK701
# (Or https://github.com/microsoft/terminal/releases/)

# %% [markdown]
# ### Basic Commands
# • Directory: a file system cataloging structure which contains references to other computer files, and possibly other directories.
# ![image-5.png](attachment:image-5.png)
#
# Note:\
# mv SOURCE TARGET	    Rename or move SOURCE to TARGET (for MacOS)\
# rni SOURCE TARGET	    Rename SOURCE to TARGET (for Windows)

# %% [markdown]
# ##### Path
# 1. relative path \
# Calling a path like this indicates that you want to navigate into a path that’s relative to the directory that you’re in right now.
# <img src="attachment:image.png" alt="alt text" width="100" height="100">
#
# 2. absolute/complete path  \
# you have to specify the complete path from the root directory.
# \
# MacOS:
# <img src="attachment:image-2.png" alt="alt text" width="300" height="300">
# Windows:
# <img src="attachment:image-3.png" alt="alt text" width="300" height="300">

# %% [markdown]
# ### Create Files and Folders
# Q:
# \
# (1) Create a new file named: hello_terminal.py
# \
# (2) Use the echo command to add content to hello_terminal.py
# \
# The content is: print("Hello, terminal!")
# \
# Note: For the echo command, it’s a plain string, which it outputs back into the terminal.
# \
# (3) Use the cat command to find what content in the hello_terminal.py

# %% [markdown]
# ### Create a Virtual Environment
# 1. MacOS
# ![image.png](attachment:image.png)
# 2. Windows
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### Install a Package
# e.g. rich package: enables you to create colorful text user interface (TUI) applications for the terminal.
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# # Coding

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### 1. Displaying Output with the print( ) Function

# %%
print('Hello world')
# Out:
# Hello world

# %%
print('Kate Austen')
print('123 Full Circle Drive')
print('Asheville, NC 28899')
# Out:
# Kate Austen
# 123 Full Circle Drive
# Asheville, NC 28899

# %% [markdown]
# ##### • String Literals
# Python also allows you to enclose string literals in triple quotes (either """ or ''')

# %%
print("""I'm reading "Hamlet" tonight.""")
# Out:
# I'm reading "Hamlet" tonight.

# %%
print("""One
Two
Three""")
# Out:
# One
# Two
# Three

# %% [markdown]
# Q: How can I change the above strings into string literals?

# %%
print("""
    "Monday's sales are", monday,
"and Tuesday's sales are", tuesday,
"and Wednesday's sales are", wednesday
"""
)
# Out:
#     "Monday's sales are", monday,
# "and Tuesday's sales are", tuesday,
# "and Wednesday's sales are", wednesday

# %%
print('''
total = (value1 + value2 +
value3 + value4 +
value5 + value6)
'''
)
# Out:
# total = (value1 + value2 +
# value3 + value4 +
# value5 + value6)

# %% [markdown]
# ##### • Comments

# %%
# This program displays a person's
# name and address.
print('Kate Austen')
print('123 Full Circle Drive')
print('Asheville, NC 28899')
# Out:
# Kate Austen
# 123 Full Circle Drive
# Asheville, NC 28899

# %%
print('Kate Austen') # Display the name.
print('123 Full Circle Drive') # Display the address.
print('Asheville, NC 28899') # Display the city, state, and ZIP.
# Out:
# Kate Austen
# 123 Full Circle Drive
# Asheville, NC 28899

# %% [markdown]
# ### 2. Variable Assignment
# variable = expression
# \
# = : assignment operator
# \
# variable is the name of a variable/object
# \
# expression is a value

# %%
width = 25
length = 50

#print(width)
print(width)
print(length)
# Out:
# 25
# 50

# %%
room = 503
print('I am staying in room',room)
print('I am staying in room ', room, '.', sep = '')
# Out:
# I am staying in room 503
# I am staying in room 503.

# %% [markdown]
# ##### • separator or sep parameter
# It shows between the arguments to print() function in Python is space by default (softspace feature) , which can be modified and can be made to any character, integer or string as per our choice.

# %%
print('I am staying in room ', room, '.', sep = '-')
# Out:
# I am staying in room -503-.

# %% [markdown]
# ##### Q: Can you use separator @ to show your result.

# %%
503 = room
# Out:
#   Cell In[24], line 1
#     503 = room
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %% [markdown]
# ##### Q: Why?

# %% [markdown]
# #####
# As shown in the above, an error occurs if the item on the left side of the = operator is not a variable

# %% [markdown]
# ##### • Variable Reassignment
# You can reassign the value to the same variable

# %%
print(room)
room = 1999
print(room)
# Out:
# 503
# 1999

# %% [markdown]
# ##### • Variable Naming Rules
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# #####
# ![image.png](attachment:image.png)

# %%
_a=5
print(_a)
# Out:
# 5

# %%
units per day=5
print(units per day)
# Out:
#   Cell In[33], line 1
#     units per day=5
#           ^
# SyntaxError: invalid syntax

# %%
3dGraph = 5
print(3dGraph)
# Out:
#   Cell In[40], line 1
#     3dGraph = 5
#     ^
# SyntaxError: invalid decimal literal

# %%
Mixture#3=5
print(Mixture#3)
# Out:
#   Cell In[45], line 2
#     print(Mixture#3)
#                     ^
# SyntaxError: incomplete input

# %% [markdown]
# ### 3. Variable Types

# %% [markdown]
# ##### • Strings (str)
# String is a collection of alphabets, words or other characters.
# ##### • Numeric
# integer (int)
# \
# only stores integral values, that is, whole numbers
# \
# float (float)
# \
# stores floating-point values, that is, values that have potential decimal places
#
# \
# Warning:
# \
# You cannot write currency symbols, spaces, or commas in numeric
# literals.

# %%
room = 503
type (room)
# Out:
# int

# %%
dollars = 2.75
type(dollars)
# Out:
# float

# %%
value = $4,567.99
# Out:
#   Cell In[49], line 1
#     value = $4,567.99
#             ^
# SyntaxError: invalid syntax

# %% [markdown]
# ##### • Reassigning a Variable to a Different Type

# %%
x=99
type(x)
# Out:
# int

# %%
x=str(x)
type(x)
# Out:
# str

# %%
print(x)
# Out:
# 99

# %%
x=int(x)
type(x)
# Out:
# int

# %% [markdown]
# ### 4. Input ( ) function
# • Reading Numbers with the input Function
# ![image.png](attachment:image.png)

# %%
string_value = input('How many hours did you work? ')
hours = int(string_value)
# Out:
# How many hours did you work? 234

# %%
type(hours)
# Out:
# int

# %%
hours = int(input('How many hours did you work? '))
# Out:
# How many hours did you work? 3

# %%
pay_rate = float(input('What is your hourly pay rate? '))
# Out:
# What is your hourly pay rate? 3.6

# %% [markdown]
# ### 5. Performing Calculations
# ![image.png](attachment:image.png)

# %%
999+627
# Out:
# 1626

# %%
# Assign a value to the salary variable.
salary = 2500.0

# Assign a value to the bonus variable.
bonus = 1200.0

# Calculate the total pay by adding salary
# and bonus. Assign the result to pay.
pay = salary + bonus

# Display the pay.
print('Your pay is', pay)
# Out:
# Your pay is 3700.0

# %%
999-627
# Out:
# 372

# %%
5/2
# Out:
# 2.5

# %%
5//2
# Out:
# 2

# %%
5%2
# Out:
# 1

# %%
5**2
# Out:
# 25

# %% [markdown]
# Q: Tell the difference?
# \
# • 10*3
# \
# •"pie"*3

# %% [markdown]
# ##### • Operator Precedence
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 6. String Concatenation
# • Use the + operator to concatenate strings

# %%
message = 'Hello ' + 'world' 
print(message)
# Out:
# Hello world

# %% [markdown]
# • Two or more string literals written adjacent to each other are implicitly concatenated into a single string.

# %%
my_str = 'one' 'two' 'three'
print(my_str)
# Out:
# onetwothree

# %% [markdown]
# ##### • Escape Characters
# ![image.png](attachment:image.png)

# %%
print('One\nTwo\nThree')
# Out:
# One
# Two
# Three

# %%
print('Mon\tTues\tWed')
print('Thur\tFri\tSat')
# Out:
# Mon	Tues	Wed
# Thur	Fri	Sat

# %%
print("Your assignment is to read \"Hamlet\" by tomorrow.")
print('I\'m ready to begin.')
# Out:
# Your assignment is to read "Hamlet" by tomorrow.
# I'm ready to begin.

# %%
print('The path is C:\\temp\\data.')
# Out:
# The path is C:\temp\data.

# %%
print('Enter the amount of '
      'sales for each day')
# Out:
# Enter the amount of sales for each day

# %%
print('Enter the amount of'
      '\nsales for each day')
# Out:
# Enter the amount of
# sales for each day

# %%
print('Enter the amount of'
      '\tsales for each day')
# Out:
# Enter the amount of	sales for each day

# %% [markdown]
# ### 7. Displaying Formatted Output With F-Strings

# %% [markdown]
# • An f-string is a special type of string literal that is prefixed with the letter f

# %%
print(f'Hello world')
# Out:
# Hello world

# %% [markdown]
# • An f-string can contain placeholders for variables and other expressions

# %%
name = 'Johnny'
print(f'Hello {name}.')
# Out:
# Hello Johnny.

# %%
print(f'The value is {10 + 2}.')
# Out:
# The value is 12.

# %%
val = 10 
print(f'The value is {val + 2}.')
# Out:
# The value is 12.

# %% [markdown]
# ###### References:
# https://en.wikipedia.org/wiki/Computer_terminal
# \
# https://realpython.com/terminal-commands/
# \
# https://en.wikipedia.org/wiki/Directory_(computing)
# \
# Textbook: Starting Out with Python by Tony Gaddis, 5th edition, 2020
# \
# Print ISBN: 9780136679110, 0136679110
# \
# eText ISBN: 9780136719199, 0136719198
